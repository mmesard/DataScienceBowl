# %%
# %matplotlib inline

# %%
import numpy as np

# %%
import math

# %%
import glob

# %%
import matplotlib.pyplot as plt

# %%
import dsb2017

# %%
from dsb2017 import image_preprocessing

# %%
def previewImageSlices(image, depthStep):
    sliceNums = range(0,image.shape[0],depthStep)
    numPreviewSlices = len(sliceNums)
    previewGridSize = int(math.ceil(math.sqrt(numPreviewSlices)))
    fig = plt.figure(figsize=(20,20))
    for ix, sliceNum in enumerate(sliceNums):
        fig.add_subplot(previewGridSize, previewGridSize, ix+1)
        plt.imshow(image[int(sliceNum),:,:], cmap=plt.cm.gray, vmin=0, vmax=1)

# %%
sampleImagePaths = glob.glob('example_preprocessed/*.npy')
sampleImagePaths
# Out:
# ['example_preprocessed\\0a099f2549429d29b32f349e95fb2244.npy',
#  'example_preprocessed\\0a0c32c9e08cc2ea76a71649de56be6d.npy',
#  'example_preprocessed\\0a38e7597ca26f9374f8ea2770ba870d.npy',
#  'example_preprocessed\\0acbebb8d463b4b9ca88cf38431aac69.npy',
#  'example_preprocessed\\0b20184e0cd497028bdd155d9fb42dc9.npy']

# %%
sampleImage = np.load(sampleImagePaths[0])
sampleImage.shape
# Out:
# (160L, 174L, 174L)

# %%
sampleImage.shape
# Out:
# (160L, 174L, 174L)

# %%
standardizedImage = image_preprocessing.standardize_volume(sampleImage,256, fillValue=0.0)
standardizedImage.shape
# Out:
# (256L, 256L, 256L)

# %%
previewImageSlices(sampleImage, 20)

# %%
previewImageSlices(standardizedImage, 20)
